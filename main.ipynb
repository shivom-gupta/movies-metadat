# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast
# %matplotlib inline

# %%
df= pd.read_csv('movies-metadata.csv')
df.head()
# Out:
# c:\Users\Admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %%
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
columns = ['id','title','budget', 'genres','original_language','popularity', 'production_companies', 'production_countries',
           'release_date', 'revenue', 'runtime','spoken_languages','vote_average', 'vote_count']

# %%
df=df[columns]

# %%
df.head()
# Out:
#       id                        title    budget  \
# 0    862                    Toy Story  30000000
# 1   8844                      Jumanji  65000000
# 2  15602             Grumpier Old Men         0
# 3  31357            Waiting to Exhale  16000000
# 4  11862  Father of the Bride Part II         0
#
#                                               genres original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...                en
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...                en
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...                en
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...                en
# 4                     [{'id': 35, 'name': 'Comedy'}]                en
#
#   popularity                               production_companies  \
# 0  21.946943     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  17.015539  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    45466 non-null  object
#  1   title                 45460 non-null  object
#  2   budget                45466 non-null  object
#  3   genres                45466 non-null  object
#  4   original_language     45455 non-null  object
#  5   popularity            45461 non-null  object
#  6   production_companies  45463 non-null  object
#  7   production_countries  45463 non-null  object
#  8   release_date          45379 non-null  object
#  9   revenue               45460 non-null  float64
#  10  runtime               45203 non-null  float64
#  11  spoken_languages      45460 non-null  object
#  12  vote_average          45460 non-null  float64
#  13  vote_count            45460 non-null  float64
# dtypes: float64(4), object(10)
# ...

# %%
df.budget = pd.to_numeric(df['budget'], errors= 'coerce')

# %%
df.release_date = pd.to_datetime(df['release_date'], errors='coerce')

# %%
df.popularity= pd.to_numeric(df['popularity'], errors= 'coerce')

# %%
df.describe()
# Out:
#              budget    popularity       revenue       runtime  vote_average  \
# count  4.546300e+04  45460.000000  4.546000e+04  45203.000000  45460.000000
# mean   4.224579e+06      2.921478  1.120935e+07     94.128199      5.618207
# std    1.742413e+07      6.005414  6.433225e+07     38.407810      1.924216
# min    0.000000e+00      0.000000  0.000000e+00      0.000000      0.000000
# 25%    0.000000e+00      0.385948  0.000000e+00     85.000000      5.000000
# 50%    0.000000e+00      1.127685  0.000000e+00     95.000000      6.000000
# 75%    0.000000e+00      3.678902  0.000000e+00    107.000000      6.800000
# max    3.800000e+08    547.488298  2.787965e+09   1256.000000     10.000000
#
#          vote_count
# count  45460.000000
# mean     109.897338
# std      491.310374
# min        0.000000
# 25%        3.000000
# 50%       10.000000
# 75%       34.000000
# max    14075.000000

# %%
df.isna().sum()
# Out:
# id                        0
# title                     6
# budget                    3
# genres                    0
# original_language        11
# popularity                6
# production_companies      3
# production_countries      3
# release_date             90
# revenue                   6
# runtime                 263
# spoken_languages          6
# vote_average              6
# vote_count                6
# dtype: int64

# %%
df.corr()
# Out:
#                 budget  popularity   revenue   runtime  vote_average  \
# budget        1.000000    0.449645  0.768776  0.134733      0.073494
# popularity    0.449645    1.000000  0.506179  0.129927      0.154399
# revenue       0.768776    0.506179  1.000000  0.103917      0.083868
# runtime       0.134733    0.129927  0.103917  1.000000      0.158146
# vote_average  0.073494    0.154399  0.083868  0.158146      1.000000
# vote_count    0.676642    0.559965  0.812022  0.113539      0.123607
#
#               vote_count
# budget          0.676642
# popularity      0.559965
# revenue         0.812022
# runtime         0.113539
# vote_average    0.123607
# vote_count      1.000000

# %%
import missingno
missingno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df.revenue.replace(np.nan, 0)
# Out:
# 0        373554033.0
# 1        262797249.0
# 2                0.0
# 3         81452156.0
# 4         76578911.0
#             ...
# 45461            0.0
# 45462            0.0
# 45463            0.0
# 45464            0.0
# 45465            0.0
# Name: revenue, Length: 45466, dtype: float64

# %%
df['spoken_languages'] = df['spoken_languages'].fillna('[]').apply(ast.literal_eval)
df['spoken_languages'] = df['spoken_languages'].apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])

# %%
df['production_companies'] = df['production_companies'].fillna('[]').apply(ast.literal_eval)
df['production_companies'] = df['production_companies'].apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])
df['production_countries'] = df['production_countries'].fillna('[]').apply(ast.literal_eval)
df['production_countries'] = df['production_countries'].apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])

# %%
df['genres'] = df['genres'].fillna('[]').apply(ast.literal_eval)
df['genres'] = df['genres'].apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])

# %%
df.head()
# Out:
#       id                        title      budget  \
# 0    862                    Toy Story  30000000.0
# 1   8844                      Jumanji  65000000.0
# 2  15602             Grumpier Old Men         0.0
# 3  31357            Waiting to Exhale  16000000.0
# 4  11862  Father of the Bride Part II         0.0
#
#                          genres original_language  popularity  \
# 0   [Animation, Comedy, Family]                en   21.946943
# 1  [Adventure, Fantasy, Family]                en   17.015539
# 2             [Romance, Comedy]                en   11.712900
# 3      [Comedy, Drama, Romance]                en    3.859495
# 4                      [Comedy]                en    8.387519
#
#                                 production_companies  \
# 0                          [Pixar Animation Studios]
# 1  [TriStar Pictures, Teitler Film, Interscope Co...
# 2                     [Warner Bros., Lancaster Gate]
# 3           [Twentieth Century Fox Film Corporation]
# ...

# %%
df.dtypes
# Out:
# id                              object
# title                           object
# budget                         float64
# genres                          object
# original_language               object
# popularity                     float64
# production_companies            object
# production_countries            object
# release_date            datetime64[ns]
# revenue                        float64
# runtime                        float64
# spoken_languages                object
# vote_average                   float64
# vote_count                     float64
# dtype: object

# %% [markdown]
# df.to_excel('cleaned.xlsx')

# %%
sns.regplot(data=df, x='budget', y='revenue')
plt.xlabel('Budget')
plt.ylabel('Revenue')
plt.title('Revenue VS Budget');

# %%
df['month'] = df['release_date'].dt.month_name()
df.month = pd.Categorical(df['month'], categories=['January', 'Feburary', 'March', 'April', 'May', 'June', 'July', 'August', 'September','October', 'November', 'December'],ordered=True)

# %%
sns.lineplot(data=df, x='month', y='revenue')
plt.title('Month vs Revenue')
plt.xlabel('Month')
plt.ylabel('Revenue')
plt.xticks(rotation=30);

# %%
df['day']=df['release_date'].dt.day_name()
df['day']= pd.Categorical(df['day'], categories=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'], ordered=True)

# %%
sns.lineplot(data=df, x='day', y='revenue')
plt.xlabel('Day of week')
plt.ylabel('Revenue')
plt.title('Day of the week VS Revenue')
plt.xticks(rotation=30);

# %%
df.genres = df.genres.astype(str)

# %%
y=df.groupby('genres')['revenue'].mean().sort_values(ascending=False)
y=pd.DataFrame(y)
y.reset_index(inplace=True)
y=y.head(10)

# %%
sns.barplot(data=y, x='revenue', y='genres',color=sns.color_palette()[0])
plt.xlabel('Revenue')
plt.ylabel('Genres')
plt.title('Mean Revenue VS Genres');

# %%
sns.regplot(data=df, x='popularity', y='revenue')
plt.xlabel('Popularity')
plt.ylabel('Revenue')
plt.title('Revenue VS Popularity');

# %%
sns.regplot(data=df, x='vote_count', y='revenue')
plt.title('Number of votes VS Revenue')
plt.xlabel('Number of Votes')
plt.ylabel('Revenue');

# %%
sns.regplot(data=df, x='vote_average', y='revenue')
plt.title('Average score from votes VS Revenue')
plt.xlabel('Average score from votes')
plt.ylabel('Revenue');
